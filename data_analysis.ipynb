# %%
import pandas as pd

# Import all datasets
df_2019 = pd.read_csv("datasets/cleaned/cleaned_dataset_2019.csv")
# df_2019.head()

df_2020 = pd.read_csv("datasets/cleaned/cleaned_dataset_2020.csv")
# df_2020.head()

df_2021 = pd.read_csv("datasets/cleaned/cleaned_dataset_2021.csv")
# df_2021.head()

df_2022 = pd.read_csv("datasets/cleaned/cleaned_dataset_2022.csv")
# df_2022.head()

df_2023 = pd.read_csv("datasets/cleaned/cleaned_dataset_2023.csv")
# df_2023.head()

# %%
grp = df_2019.groupby("EdLevel")
grp.describe()
# Out:
#                                                    Unnamed: 0.1                \
#                                                           count          mean
# EdLevel
# Associate degree                                         1566.0  25621.600255
# Bachelor’s degree (BA, BS, B.Eng., etc.)                23371.0  25340.438235
# I never completed any formal education                    182.0  26442.719780
# Master’s degree (MA, MS, M.Eng., MBA, etc.)             11345.0  25101.321816
# Other doctoral degree (Ph.D, Ed.D., etc.)                 992.0  25613.553427
# Primary/elementary school                                 214.0  26375.233645
# Professional degree (JD, MD, etc.)                        633.0  24567.214850
# Secondary school (e.g. American high school, Ge...       2463.0  25208.119773
# Some college/university study without earning a...       5534.0  25050.678533
#
#                                                                         \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

labels = ["College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Others"]
sizes = [5273, 22269, 11058, (178+194+2205+1497+607+975)]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title('2019 Stack Overflow Developer Survey: Highest Level of Education attained by the respondents.')

plt.savefig("figures/2019/final/edlevel_piechart.png", bbox_inches = "tight")
plt.show()

# %%
grp = df_2020.groupby("EdLevel")
grp.describe()
# Out:
#                                                    Unnamed: 0.1                \
#                                                           count          mean
# EdLevel
# Associate degree (A.A., A.S., etc.)                      1019.0  15263.548577
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)            14704.0  15734.630849
# I never completed any formal education                    132.0  15636.840909
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          7314.0  15875.916598
# Other doctoral degree (Ph.D., Ed.D., etc.)                692.0  16261.001445
# Primary/elementary school                                 123.0  16020.609756
# Professional degree (JD, MD, etc.)                        390.0  15555.466667
# Secondary school (e.g. American high school, Ge...       1281.0  15675.444965
# Some college/university study without earning a...       3508.0  15984.464652
#
#                                                                         \
# ...

# %%
labels = ["College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Others"]
sizes = [3508, 14704, 7314, (1019+132+692+123+390+1281)]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title('2020 Stack Overflow Developer Survey: Highest Level of Education attained by the respondents.')

plt.savefig("figures/2020/final/edlevel_piechart.png", bbox_inches = "tight")
plt.show()

# %%
grp = df_2021.groupby("EdLevel")
grp.describe()
# Out:
#                                                    Unnamed: 0.1                \
#                                                           count          mean
# EdLevel
# Associate degree (A.A., A.S., etc.)                      1241.0  21414.345689
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)            20468.0  21441.163572
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         10325.0  21277.004455
# Other doctoral degree (Ph.D., Ed.D., etc.)               1090.0  22428.446789
# Primary/elementary school                                 208.0  20846.778846
# Professional degree (JD, MD, etc.)                        686.0  21553.390671
# Secondary school (e.g. American high school, Ge...       1837.0  20959.567774
# Some college/university study without earning a...       5102.0  21114.018816
# Something else                                            426.0  21959.446009
#
#                                                                         \
# ...

# %%
labels = ["College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Others"]
sizes = [5102, 20468, 10325, (1241+1090+208+686+1837+426)]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title('2021 Stack Overflow Developer Survey: Highest Level of Education attained by the respondents.')

plt.savefig("figures/2021/final/edlevel_piechart.png", bbox_inches = "tight")
plt.show()

# %%
grp = df_2022.groupby("EdLevel")
grp.describe()
# Out:
#                                                    Unnamed: 0.1                \
#                                                           count          mean
# EdLevel
# Associate degree (A.A., A.S., etc.)                      1140.0  17218.385965
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)            16366.0  17601.656727
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          8628.0  17267.157395
# Other doctoral degree (Ph.D., Ed.D., etc.)                881.0  17273.807037
# Primary/elementary school                                 200.0  15789.570000
# Professional degree (JD, MD, etc.)                        564.0  18428.359929
# Secondary school (e.g. American high school, Ge...       1594.0  17643.504391
# Some college/university study without earning a...       4011.0  17741.732236
# Something else                                            317.0  18299.283912
#
#                                                                          \
# ...

# %%
labels = ["College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Others"]
sizes = [4011, 16366, 8628, (1140+881+200+564+1594+317)]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title('2022 Stack Overflow Developer Survey: Highest Level of Education attained by the respondents.')

plt.savefig("figures/2022/final/edlevel_piechart.png", bbox_inches = "tight")
plt.show()

# %%
grp = df_2023.groupby("EdLevel")
grp.describe()
# Out:
#                                                    Unnamed: 0.1                \
#                                                           count          mean
# EdLevel
# Associate degree (A.A., A.S., etc.)                      1483.0  22842.020229
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)            21176.0  22283.863666
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)         11844.0  21634.348193
# Primary/elementary school                                 205.0  24309.209756
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)           1671.0  22187.656493
# Secondary school (e.g. American high school, Ge...       2000.0  22802.656000
# Some college/university study without earning a...       5223.0  22552.830749
# Something else                                            453.0  22046.401766
#
#                                                                         \
#                                                              std   min
# EdLevel
# ...

# %%
labels = ["College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Others"]
sizes = [5223, 21176, 11844, (1483+205+1671+2000+453)]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.title('2023 Stack Overflow Developer Survey: Highest Level of Education attained by the respondents.')

plt.savefig("figures/2023/final/edlevel_piechart.png", bbox_inches = "tight")
plt.show()

# %%
# Calculate the average salary for each level of education
print(df_2019.groupby(["EdLevel"])["ConvertedComp"].mean())
# Out:
# EdLevel
# Associate degree                                                                      59694.494891
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              63547.652989
# I never completed any formal education                                                60946.758242
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           65229.949669
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             90103.266129
# Primary/elementary school                                                             49851.962617
# Professional degree (JD, MD, etc.)                                                    41048.853081
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    46472.444580
# Some college/university study without earning a degree                                60438.351644
# Name: ConvertedComp, dtype: float64

# %%
avgsalary_edlevel_2019 = pd.DataFrame({"EdLevel": ["Primary/elementary school", "Secondary school", "Associate degree", "College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Professional degree", "Doctorate degree"],
                    "AverageSalary": [53259, 49683, 60671, 62259, 65015, 65912, 40892, 90589]})

# %%
print(df_2020.groupby(["EdLevel"])["ConvertedComp"].mean())
# Out:
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                   60022.229637
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          59232.137990
# I never completed any formal education                                                57190.409091
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       62958.214794
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            79194.261561
# Primary/elementary school                                                             52798.780488
# Professional degree (JD, MD, etc.)                                                    40507.748718
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    47159.608119
# Some college/university study without earning a degree                                56746.668472
# Name: ConvertedComp, dtype: float64

# %%
avgsalary_edlevel_2020 = pd.DataFrame({"EdLevel": ["Primary/elementary school", "Secondary school", "Associate degree", "College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Professional degree", "Doctorate degree"],
                    "AverageSalary": [52798, 47159, 60022, 56746, 59232, 62958, 40507, 79194]})

# %%
print(df_2021.groupby(["EdLevel"])["ConvertedCompYearly"].mean())
# Out:
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                   66646.174859
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          67591.173441
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       72285.777821
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            96774.754128
# Primary/elementary school                                                             62956.399038
# Professional degree (JD, MD, etc.)                                                    48022.205539
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    53874.477953
# Some college/university study without earning a degree                                65219.243434
# Something else                                                                        55348.007042
# Name: ConvertedCompYearly, dtype: float64

# %%
avgsalary_edlevel_2021 = pd.DataFrame({"EdLevel": ["Primary/elementary school", "Secondary school", "Associate degree", "College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Professional degree", "Doctorate degree"],
                    "AverageSalary": [62956, 53874, 66646, 65219, 67591, 72285, 48022, 96774]})

# %%
print(df_2022.groupby(["EdLevel"])["ConvertedCompYearly"].mean())
# Out:
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                    79850.209649
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           84099.787731
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        88638.119726
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            113671.072645
# Primary/elementary school                                                              74869.030000
# Professional degree (JD, MD, etc.)                                                     66514.523050
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     69008.998745
# Some college/university study without earning a degree                                 80803.711543
# Something else                                                                         62707.138801
# Name: ConvertedCompYearly, dtype: float64

# %%
avgsalary_edlevel_2022 = pd.DataFrame({"EdLevel": ["Primary/elementary school", "Secondary school", "Associate degree", "College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Professional degree", "Doctorate degree"],
                    "AverageSalary": [74869, 69008, 79850, 80803, 84099, 88638, 66514, 113671]})

# %%
print(df_2023.groupby(["EdLevel"])["ConvertedCompYearly"].mean())
# Out:
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                    85047.558328
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           93398.713071
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        91137.969605
# Primary/elementary school                                                              72825.326829
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                        100747.433872
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     67641.982000
# Some college/university study without earning a degree                                 84851.043079
# Something else                                                                         65332.573951
# Name: ConvertedCompYearly, dtype: float64

# %%
avgsalary_edlevel_2023 = pd.DataFrame({"EdLevel": ["Primary/elementary school", "Secondary school", "Associate degree", "College/University (Incomplete)", "Bachelor's degree", "Master's degree", "Professional degree"],
                    "AverageSalary": [72825, 67641, 85047, 84851, 93398, 91137, 100747]})

# %%
# import matplotlib.pyplot as plt
# Plot a bar graph
# average_salary_by_ed_level.plot(kind='bar', color='skyblue', alpha=0.7)
# # Add labels and title
# plt.xlabel('Highest Education Level attained')
# plt.ylabel('Average Salary ($)')
# plt.title('Average Salary by Education Level')
# # Show the plot
# plt.show()

import seaborn as sns
from matplotlib import pyplot

# color_palette = sns.color_palette("tab10")

avgsalary_edlevel_2019["ds"] = "2019"
avgsalary_edlevel_2020["ds"] = "2020"
avgsalary_edlevel_2021["ds"] = "2021"
avgsalary_edlevel_2022["ds"] = "2022"
avgsalary_edlevel_2023["ds"] = "2023"

dss = pd.concat([avgsalary_edlevel_2019, avgsalary_edlevel_2020, avgsalary_edlevel_2021, avgsalary_edlevel_2022, avgsalary_edlevel_2023])
bar_plot_1 = sns.barplot(x="EdLevel", y="AverageSalary", hue="ds", data=dss, palette=sns.color_palette("Set2"))
bar_plot_1.set_xticklabels(pyplot.xticks()[1], rotation=45, horizontalalignment="right")
bar_plot_1.set_xlabel("Highest Education Level Attained")
bar_plot_1.set_ylabel("Average Yearly Salary ($)")

bar_plot_1.get_figure().savefig("figures/avgsalary_edlevel_barchart.png", bbox_inches = "tight")

# %%
# Calculate the average salary compared to years of experience
average_salary_by_years_code = df_2019_no_outliers.groupby(["YearsCode"])["ConvertedComp"].mean()

print("Average salary by years of coding experience:")
print(average_salary_by_years_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 # Calculate the average salary compared to years of experience
# ----> 2 average_salary_by_years_code = df_2019_no_outliers.groupby(["YearsCode"])["ConvertedComp"].mean()
#       4 print("Average salary by years of coding experience:")
#       5 print(average_salary_by_years_code)
#
# NameError: name 'df_2019_no_outliers' is not defined

# %%
print(type(average_salary_by_years_code))

# Create a scatter plot
plt.scatter(average_salary_by_years_code["YearsCode"], average_salary_by_years_code["ConvertedComp"], color='blue', marker='o')
average_salary_by_years_code.plot(kind='bar', color='skyblue', alpha=0.7)

# Add labels and title
plt.xlabel('Years of Experience')
plt.ylabel('Average Salary ($)')
plt.title('Average Salary by Years of Experience')

# Show the plot
plt.show()
